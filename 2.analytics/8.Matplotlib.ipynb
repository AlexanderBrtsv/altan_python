# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.random.randint(20, size=5)
x
# Out:
# array([14, 19, 18,  9,  5])

# %%
y1 = np.random.randint(10, size=5)
y2 = np.random.randint(10, size=5)

print(y1, y2)
# Out:
# [8 0 8 4 7] [3 4 4 2 2]

# %%
# интерактивный режим
#%matplotlib notebook
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
x = np.linspace(-10, 10, 1000)
# настройка габаритов окна
plt.figure(figsize=(10, 5), dpi=100)
plt.plot(x, np.sin(x), label="sinusoid")
plt.plot(x, np.cos(x), label="cosine")
# настройка легенды
plt.legend(loc="lower center", framealpha=0.5, fancybox=True, shadow=True)

# сетка
plt.grid(True)
plt.show()

# %% [markdown]
# - Гистограммы

# %%
#data = np.arange(10)
data = np.random.randint(10, size=10)
data
# Out:
# array([8, 5, 8, 3, 1, 2, 1, 8, 2, 5])

# %%
plt.hist(data)
plt.show()

# %%
# нормальное распределение (гауссова)
# медиана = 0 , стандартное = 2
data = np.random.randn(1000)
data
# Out:
# array([ 5.20126324e-01,  1.23197557e+00, -1.82447118e+00, -1.70893547e+00,
#         1.59363592e+00, -8.22380119e-01,  1.66393117e+00, -2.71295974e-01,
#         1.16526028e+00, -6.31394925e-01, -3.58059632e-01,  5.85082939e-03,
#        -1.47549026e+00,  3.93658633e-01, -1.15345700e+00, -4.37139132e-02,
#        -2.69679689e-01,  1.19624681e+00, -4.99856707e-01, -7.97284328e-01,
#        -1.81797826e+00, -3.06206159e-01, -1.04984147e+00,  9.90939911e-01,
#         7.59498370e-01, -1.60797322e+00, -1.06645900e+00,  8.13787403e-01,
#         1.13530457e+00,  4.57075167e-01, -2.62271126e-01, -1.01470925e+00,
#        -2.37732009e+00,  1.13049492e+00, -1.57178765e-01,  9.28422376e-01,
#        -1.38609166e+00, -4.06418347e-01,  3.96426907e-01,  1.71408453e+00,
#         6.19927922e-01,  5.39751764e-02, -6.24462507e-01, -9.03011209e-01,
#        -1.61308563e-01,  1.49915605e+00, -3.32699744e-01,  6.86640313e-01,
# ...

# %%
plt.hist(data, bins=50)
plt.show()

# %%
data_1 = np.random.normal(0, 0.5, 1000)
data_2 = np.random.normal(0, 2, 1000)
data_3 = np.random.normal(4, 1, 1000)

plt.figure(figsize=(8, 5))
plt.hist(data_1, bins=50, color="r")
plt.hist(data_2, bins=50, alpha=0.5, color="m", histtype="barstacked", edgecolor="k", lw=5)
plt.hist(data_3, bins=50, alpha=0.5, color="b")

plt.show()

# %%
import matplotlib.animation as animation

# %%
# Fixing bin edges
HIST_BINS = np.linspace(-4, 4, 100)
# histogram our data with numpy
data = np.random.randn(1000)
n, _ = np.histogram(data, HIST_BINS)

# %%
def prepare_animation(bar_container):

    def animate(frame_number):
        # simulate new data coming in
        data = np.random.randn(1000)
        n, _ = np.histogram(data, HIST_BINS)
        for count, rect in zip(n, bar_container.patches):
            rect.set_height(count)
        return bar_container.patches
    return animate

# %%
fig, ax = plt.subplots()
_, _, bar_container = ax.hist(data, HIST_BINS, lw=1, ec="yellow", fc="green", alpha=0.5)
ax.set_ylim(top=55)  # set safe limit to ensure that all data is visible.

ani = animation.FuncAnimation(fig, prepare_animation(bar_container), 50,
                              repeat=False, blit=True)
plt.show()

# %%
# Fixing bin edges
HIST_BINS = np.linspace(-4, 4, 100)
# %matplotlib notebook
# histogram our data with numpy
data = np.random.randn(1000)
n, _ = np.histogram(data, HIST_BINS)
def prepare_animation(bar_container):

    def animate(frame_number):
        # simulate new data coming in
        data = np.random.randn(1000)
        n, _ = np.histogram(data, HIST_BINS)
        for count, rect in zip(n, bar_container.patches):
            rect.set_height(count)
        return bar_container.patches
    return animate
fig, ax = plt.subplots()
_, _, bar_container = ax.hist(data, HIST_BINS, lw=1, ec="yellow", fc="green", alpha=0.5)
ax.set_ylim(top=55)  # set safe limit to ensure that all data is visible.

ani = animation.FuncAnimation(fig, prepare_animation(bar_container), 50,
                              repeat=False, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - диаграмма рассеивания

# %%
x = np.linspace(0, 10, 10)
y = np.sin(x)

plt.scatter(x, y, marker="*")
plt.show()
